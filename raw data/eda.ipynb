# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# convert json to csv file
# df = pd.read_json('./db.json')
# df.to_csv('./db.csv', index=False)

df = pd.read_csv('./db.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9988 entries, 0 to 9987
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TotalEmployees            9158 non-null   object
#  1   TotalEmployeesIndia       8364 non-null   object
#  2   Rating                    9988 non-null   float64
#  3   UrlName                   9988 non-null   object
#  4   CompanyType               8423 non-null   object
#  5   Name                      9988 non-null   object
#  6   CompanyReviewsLive        9988 non-null   int64
#  7   CompanySalaries           9988 non-null   int64
#  8   InterviewExperiencesLive  9988 non-null   int64
#  9   Age                       9988 non-null   int64
#  10  ShortName                 9988 non-null   object
#  11  Logo                      9639 non-null   object
#  12  HQCountry                 9625 non-null   object
#  13  headquaters               9673 non-null   object
#  14  CompanyJobsLive           9988 non-null   int64
#  15  HQUrlName                 6250 non-null   object
#  16  CompanyId                 9988 non-null   int64
#  17  location_count            9988 non-null   int64
#  18  industry_string           9870 non-null   object
#  19  Subscribed                9988 non-null   int64
# dtypes: float64(1), int64(8), object(11)
# memory usage: 1.5+ MB

# %%
df.head(5)
# Out:
#   TotalEmployees TotalEmployeesIndia  Rating     UrlName CompanyType  \
# 0        100001+             100001+    3.92         tcs      Public
# 1        100001+             100001+    4.14   accenture      Public
# 2        100001+             100001+    3.94   cognizant     Private
# 3   50001-100000        50001-100000    4.02  icici-bank      Public
# 4        100001+             100001+    3.93       wipro      Public
#
#                         Name  CompanyReviewsLive  CompanySalaries  \
# 0  Tata Consultancy Services               41589           394003
# 1                  Accenture               27770           268685
# 2                  Cognizant               25176           272214
# 3                 ICICI Bank               32063           100049
# 4                      Wipro               23674           200635
#
#    InterviewExperiencesLive  Age   ShortName                            Logo  \
# 0                      2783   54         TCS                             tcs
# 1                      2177   33   Accenture                       accenture
# 2                      1748   28   Cognizant  cognizant-technology-solutions
# 3                       940   28  ICICI Bank                      icici_bank
# 4                      1819   77       Wipro                           wipro
#
#              HQCountry                    headquaters  CompanyJobsLive  \
# 0                India             Mumbai,Maharashtra               55
# 1              Ireland                  Dublin,Dublin             7294
# 2  United States (USA)             Teaneck,New Jersey              316
# 3                India             Mumbai,Maharashtra              150
# 4                India  Bangalore/Bengaluru,Karnataka              520
#
#    HQUrlName  CompanyId  location_count  \
# 0     mumbai         42             240
# 1        NaN        273             132
# 2        NaN         43              88
# 3     mumbai        134             995
# 4  bengaluru         44             254
#
#                               industry_string  Subscribed
# 0  BPO / Call Centre,IT Services & Consulting           0
# 1   IT Services & Consulting,Software Product           0
# 2                    IT Services & Consulting           0
# 3                  Financial Services,Banking           0
# 4                    IT Services & Consulting           0

# %% [markdown]
# ## Kiểm tra dữ liệu trống ở các cột

# %%
df.apply(lambda x :(x.isnull().mean())*100)

# %% [markdown]
# ## Top 20 công ty rating cao nhất

# %%
top20_company = df.sort_values(by='Rating', ascending=False)[:20]

# %%
fig, ax = plt.subplots(figsize=(10, 5), dpi=100)
plt.yticks(size=12)
sns.set(style="darkgrid")
sns.barplot(data=top20_company, x='Rating', y='Name', palette='plasma')
ax.set_xlabel('Rating', fontsize=16, color = '#333F4B')
ax.set_ylabel('Name', fontsize=16, color = '#333F4B')
fig.suptitle('High rating company',fontsize=18, color = '#333F4B')
# Out:
# Text(0.5, 0.98, 'High rating company')

# %% [markdown]
# ## Phân bố các công ty

# %%
fig, ax = plt.subplots(figsize = (15,8))
sns.distplot(df['Rating'], color="purple")
plt.title("Distribution of ratings among companies", size = 20)

# %% [markdown]
# - Phân bố điểm rating của các công ty gần giống với phân bố chuẩn
# - Phần lớn các công ty rating trong khoảng 3.7 tới 4.3

# %%
# df.TotalEmployees = df.TotalEmployees.replace({'100001+': 100001, '10000+': 10000, '94072': 94072})

# df.TotalEmployees = df.TotalEmployees.replace({
#     '50001-100000': int(np.floor((50001 + 100000) / 2)),
#     '10001-50000': int(np.floor((10001 + 50000) / 2)),
#     '5001-10000': int(np.floor((5001 + 10000) / 2)),
#     '1001-5000': int(np.floor((1001 + 5000) / 2)),
#     '501-1000': int(np.floor((501 + 1000) / 2)),
#     '201-500': int(np.floor((201 + 500) / 2)),
#     '51-200': int(np.floor((51 + 200) / 2)),
#     '11-50': int(np.floor((11 + 50) / 2)),
#     '1-10': int(np.floor((1 + 10) / 2)),
#     })

# remove nan value from TotalEmployees
# df = df.dropna(subset=['TotalEmployees'])

# %% [markdown]
# ## Số lượng nhân viên ở các công ty

# %%
totalEmployees = []

df['TotalEmployees'].apply(lambda x: totalEmployees.append(x))
# remove nan value from totalEmployees
totalEmployees = [x for x in totalEmployees if str(x) != 'nan']
unique, counts = np.unique(totalEmployees, return_counts=True)
te_dataframe = pd.DataFrame({"unique":unique,"counts":counts})
te_dataframe = te_dataframe.sort_values(['counts'],ascending=[False])

fig, ax = plt.subplots(figsize=(10, 5), dpi=100)
plt.xticks(size=10, rotation=45)
plt.yticks(size=12)
sns.set(style="darkgrid")
# plot the data
sns.barplot(data=te_dataframe[:20], x='unique', y='counts', palette='plasma')
# set x and y-axis labels and title
ax.set_xlabel('Employees', fontsize=16, color = '#333F4B')
ax.set_ylabel('Counts', fontsize=16, color = '#333F4B')
fig.suptitle('Frequency of employee in companies',fontsize=18, color = '#333F4B')
# Out:
# Text(0.5, 0.98, 'Frequency of employee in companies')

# %%
indiaEmployees = []

df['TotalEmployeesIndia'].apply(lambda x: indiaEmployees.append(x))
# remove nan value from totalEmployees
indiaEmployees = [x for x in indiaEmployees if str(x) != 'nan']
unique, counts = np.unique(indiaEmployees, return_counts=True)
te_dataframe = pd.DataFrame({"unique":unique,"counts":counts})
te_dataframe = te_dataframe.sort_values(['counts'],ascending=[False])

fig, ax = plt.subplots(figsize=(10, 5), dpi=100)
plt.xticks(size=10, rotation=45)
plt.yticks(size=12)
sns.set(style="darkgrid")
# plot the data
sns.barplot(data=te_dataframe[:20], x='unique', y='counts', palette='plasma')
# set x and y-axis labels and title
ax.set_xlabel('Employees', fontsize=16, color = '#333F4B')
ax.set_ylabel('Counts', fontsize=16, color = '#333F4B')
fig.suptitle('Frequency of employee in India',fontsize=18, color = '#333F4B')
# Out:
# Text(0.5, 0.98, 'Frequency of employee in India')

# %%
top20_company_salary = df.sort_values(by='CompanySalaries', ascending=False)[:20]
fig, ax = plt.subplots(figsize=(10, 5), dpi=100)
plt.yticks(size=12)
sns.set(style="darkgrid")
sns.barplot(data=top20_company_salary, x='CompanySalaries', y='Name', palette='plasma')
ax.set_xlabel('Company Salaries ( $ )', fontsize=16, color = '#333F4B')
ax.set_ylabel('Name', fontsize=16, color = '#333F4B')
fig.suptitle('High Salary company',fontsize=18, color = '#333F4B')
# Out:
# Text(0.5, 0.98, 'High Salary company')

# %% [markdown]
# - Lương của công ty TCS cao hơn nhiều so với các công ty còn lại: 407.5k
# - Còn lại trong top 20 dao động từ 50k tới 27k
